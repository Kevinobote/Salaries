# %%
import pandas as pd

# %%
df = pd.read_csv('salaries.csv')
df.head(3)
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2025               MI              FT  Customer Success Manager
# 1       2025               SE              FT                  Engineer
# 2       2025               SE              FT                  Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   57000             EUR          60000                 NL            50
# 1  165000             USD         165000                 US             0
# 2  109000             USD         109000                 US             0
#
#   company_location company_size
# 0               NL            L
# 1               US            M
# 2               US            M

# %%
df.salary_currency.unique()
# Out:
# array(['EUR', 'USD', 'GBP', 'CAD', 'PHP', 'INR', 'BRL', 'PLN', 'CHF',
#        'TWD', 'NOK', 'SGD', 'AUD', 'JPY', 'DKK', 'CZK', 'HUF', 'MXN',
#        'ILS', 'TRY', 'ZAR', 'SEK', 'NZD', 'HKD', 'THB', 'CLP'],
#       dtype=object)

# %%
df.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.describe().T
# Out:
#                  count           mean            std      min        25%  \
# work_year      88584.0    2024.034758       0.620370   2020.0    2024.00
# salary         88584.0  161932.290289  196531.718058  14000.0  106000.00
# salary_in_usd  88584.0  157567.798417   73531.373158  15000.0  106097.25
# remote_ratio   88584.0      21.286011      40.831018      0.0       0.00
#
#                     50%       75%         max
# work_year        2024.0    2024.0      2025.0
# salary         147000.0  199500.0  30400000.0
# salary_in_usd  146307.0  198600.0    800000.0
# remote_ratio        0.0       0.0       100.0

# %%
# Correlation matrix
import matplotlib.pyplot as plt

corr_matrix = df.corr(numeric_only=True)
plt.figure(figsize=(10, 8))
plt.title('Correlation Matrix of Numeric Features')
plt.imshow(corr_matrix, cmap='coolwarm', interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(corr_matrix.columns)), corr_matrix.columns, rotation=45)
plt.yticks(range(len(corr_matrix.columns)), corr_matrix.columns)
plt.tight_layout()
plt.show()

# %%
# print the correlation matrix
print(corr_matrix)
# Out:
#                work_year    salary  salary_in_usd  remote_ratio
# work_year       1.000000 -0.033803       0.031409     -0.120347
# salary         -0.033803  1.000000       0.341281     -0.004398
# salary_in_usd   0.031409  0.341281       1.000000     -0.064520
# remote_ratio   -0.120347 -0.004398      -0.064520      1.000000

# %%
# check linearity of the features
import seaborn as sns

sns.pairplot(df, diag_kind='kde', markers='o', hue='salary_currency')
plt.show()

# %%
# Scatter plots to check linearity
sns.pairplot(df[['salary_in_usd', 'work_year', 'remote_ratio']], diag_kind='kde')
plt.show()
